# %%
import re, string, unicodedata
import pandas as pd
import nltk
from contractions import CONTRACTION_MAP
import inflect
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv('dataset.csv')
test = df.copy()

# %%
test.head()
# Out:
#                                                 text choose_one  \
# 0                 Just happened a terrible car crash   Relevant
# 1  Our Deeds are the Reason of this #earthquake M...   Relevant
# 2  Heard about #earthquake is different cities, s...   Relevant
# 3  there is a forest fire at spot pond, geese are...   Relevant
# 4             Forest fire near La Ronge Sask. Canada   Relevant
#
#                                           tidy_tweet  polarity  review_len  \
# 0                 just happened a terrible car crash     -1.00          34
# 1  our deeds are the reason of this  earthquake m...      0.00          69
# 2  heard about  earthquake is different cities  s...      0.25          64
# 3  there is a forest fire at spot pond  geese are...      0.00          96
# 4             forest fire near la ronge sask  canada      0.10          38
#
#    word_count
# 0           6
# 1          13
# 2           9
# 3          19
# 4           7

# %%
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

expand_contractions("Y'all can't expand contractions I'd think")
# Out:
# 'You all cannot expand contractions I would think'

# %%
test['contracted'] = test['text'].apply(lambda x: expand_contractions(x))

# %%
# Tokenizing
def tokenize(text):
    tweet_tokens = re.split('\W+', text)
    return tweet_tokens

test['tokens'] = test['contracted'].apply(lambda x: tokenize(x)).values

# %%
def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

def to_lowercase(words):
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def remove_punctuation(words):
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

def replace_numbers(words):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopwords.words('english'):
            new_words.append(word)
    return new_words

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, get_wordnet_pos(word))
        lemmas.append(lemma)
    return lemmas

# %%
def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = replace_numbers(words)
    words = remove_stopwords(words)
    words = lemmatize_verbs(words)
    return words

# %%
test['normalize'] = test['tokens'].apply(lambda x: normalize(x))

# %%
test.tail(25)
# Out:
#                                                     text    choose_one  \
# 10851  RT @LivingSafely: #NWS issues Severe #Thunders...      Relevant
# 10852  #??? #?? #??? #??? MH370: Aircraft debris foun...      Relevant
# 10853  Father-of-three Lost Control of Car After Over...      Relevant
# 10854  1.3 #Earthquake in 9Km Ssw Of Anza California ...      Relevant
# 10855  Evacuation order lifted for town of Roosevelt:...      Relevant
# 10856  See the 16yr old PKK suicide bomber who detona...      Relevant
# 10857  To conference attendees! The blue line from th...      Relevant
# 10858  The death toll in a #IS-suicide car bombing on...      Relevant
# 10859  #breaking #LA Refugio oil spill may have been ...      Relevant
# 10860  a siren just went off and it wasn't the Forney...      Relevant
# 10861  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...  Not Relevant
# 10862  Officials say a quarantine is in place at an A...      Relevant
# 10863  #WorldNews Fallen powerlines on G:link tram: U...      Relevant
# 10864  on the flip side I'm at Walmart and there is a...      Relevant
# 10865  Storm in RI worse than last hurricane. My city...      Relevant
# 10866  Suicide bomber kills 15 in Saudi security site...      Relevant
# 10867  #stormchase Violent Record Breaking EF-5 El Re...      Relevant
# 10868  Green Line derailment in Chicago http://t.co/U...      Relevant
# 10869  Two giant cranes holding a bridge collapse int...      Relevant
# 10870  @aria_ahrary @TheTawniest The out of control w...      Relevant
# 10871  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...      Relevant
# 10872  Police investigating after an e-bike collided ...      Relevant
# 10873  The Latest: More Homes Razed by Northern Calif...      Relevant
# 10874  MEG issues Hazardous Weather Outlook (HWO) htt...      Relevant
# 10875  #CityofCalgary has activated its Municipal Eme...      Relevant
#
#                                               tidy_tweet  polarity  \
# 10851  rt    nws issues severe  thunderstorm warnings...  0.500000
# 10852                     mh370  aircraft debris foun... -0.200000
# 10853  father of three lost control of car after over...  0.000000
# 10854  1 3  earthquake in 9km ssw of anza california ...  0.500000
# 10855   evacuation order lifted for town of roosevelt     0.000000
# 10856  see the 16yr old pkk suicide bomber who detona...  0.100000
# 10857  to conference attendees  the blue line from th...  0.000000
# 10858  the death toll in a  is suicide car bombing on...  0.000000
# 10859   breaking  la refugio oil spill may have been ...  0.000000
# 10860  a siren just went off and it wasn't the forney...  0.000000
# 10861  earthquake safety los angeles     safety faste...  0.000000
# 10862  officials say a quarantine is in place at an a...  0.000000
# 10863   worldnews fallen powerlines on g link tram  u...  0.000000
# 10864  on the flip side i'm at walmart and there is a...  0.000000
# 10865  storm in ri worse than last hurricane  my city... -0.200000
# 10866  suicide bomber kills 15 in saudi security site...  0.000000
# 10867   stormchase violent record breaking ef 5 el re... -0.350000
# 10868                  green line derailment in chicago  -0.200000
# 10869  two giant cranes holding a bridge collapse int...  0.000000
# 10870    the out of control wild fires in california ...  0.150000
# 10871        m1 94  01 04 utc  5km s of volcano hawaii    0.000000
# 10872  police investigating after an e bike collided ... -0.260417
# 10873  the latest  more homes razed by northern calif...  0.500000
# 10874        meg issues hazardous weather outlook  hwo    0.600000
# 10875   cityofcalgary has activated its municipal eme...  0.000000
#
#        review_len  word_count  \
# 10851          99          16
# 10852         100          12
# 10853          92          12
# 10854         109          18
# 10855          48           7
# 10856         106          17
# 10857         129          23
# 10858         136          28
# 10859          77          12
# 10860          65          12
# 10861          55           7
# 10862         114          19
# 10863         114          19
# 10864         114          26
# 10865         139          25
# 10866          99          15
# 10867          90          13
# 10868          33           5
# 10869          61          10
# 10870         101          18
# 10871          43          10
# 10872         137          22
# 10873          72          11
# 10874          43           6
# 10875          68           8
#
#                                               contracted  \
# 10851  RT @LivingSafely: #NWS issues Severe #Thunders...
# 10852  #??? #?? #??? #??? MH370: Aircraft debris foun...
# 10853  Father-of-three Lost Control of Car After Over...
# 10854  1.3 #Earthquake in 9Km Ssw Of Anza California ...
# 10855  Evacuation order lifted for town of Roosevelt:...
# 10856  See the 16yr old PKK suicide bomber who detona...
# 10857  To conference attendees! The blue line from th...
# 10858  The death toll in a #IS-suicide car bombing on...
# 10859  #breaking #LA Refugio oil spill may have been ...
# 10860  a siren just went off and it was not the Forne...
# 10861  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 10862  Officials say a quarantine is in place at an A...
# 10863  #WorldNews Fallen powerlines on G:link tram: U...
# 10864  on the flip side I am at Walmart and there is ...
# 10865  Storm in RI worse than last hurricane. My city...
# 10866  Suicide bomber kills 15 in Saudi security site...
# 10867  #stormchase Violent Record Breaking EF-5 El Re...
# 10868  Green Line derailment in Chicago http://t.co/U...
# 10869  Two giant cranes holding a bridge collapse int...
# 10870  @aria_ahrary @TheTawniest The out of control w...
# 10871  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...
# 10872  Police investigating after an e-bike collided ...
# 10873  The Latest: More Homes Razed by Northern Calif...
# 10874  MEG issues Hazardous Weather Outlook (HWO) htt...
# 10875  #CityofCalgary has activated its Municipal Eme...
#
#                                                   tokens  \
# 10851  [RT, LivingSafely, NWS, issues, Severe, Thunde...
# 10852  [, MH370, Aircraft, debris, found, on, La, Reu...
# 10853  [Father, of, three, Lost, Control, of, Car, Af...
# 10854  [1, 3, Earthquake, in, 9Km, Ssw, Of, Anza, Cal...
# 10855  [Evacuation, order, lifted, for, town, of, Roo...
# 10856  [See, the, 16yr, old, PKK, suicide, bomber, wh...
# 10857  [To, conference, attendees, The, blue, line, f...
# 10858  [The, death, toll, in, a, IS, suicide, car, bo...
# 10859  [, breaking, LA, Refugio, oil, spill, may, hav...
# 10860  [a, siren, just, went, off, and, it, was, not,...
# 10861  [EARTHQUAKE, SAFETY, LOS, ANGELES, ÛÒ, SAFETY,...
# 10862  [Officials, say, a, quarantine, is, in, place,...
# 10863  [, WorldNews, Fallen, powerlines, on, G, link,...
# 10864  [on, the, flip, side, I, am, at, Walmart, and,...
# 10865  [Storm, in, RI, worse, than, last, hurricane, ...
# 10866  [Suicide, bomber, kills, 15, in, Saudi, securi...
# 10867  [, stormchase, Violent, Record, Breaking, EF, ...
# 10868  [Green, Line, derailment, in, Chicago, http, t...
# 10869  [Two, giant, cranes, holding, a, bridge, colla...
# 10870  [, aria_ahrary, TheTawniest, The, out, of, con...
# 10871  [M1, 94, 01, 04, UTC, 5km, S, of, Volcano, Haw...
# 10872  [Police, investigating, after, an, e, bike, co...
# 10873  [The, Latest, More, Homes, Razed, by, Northern...
# 10874  [MEG, issues, Hazardous, Weather, Outlook, HWO...
# 10875  [, CityofCalgary, has, activated, its, Municip...
#
#                                                normalize
# 10851  [rt, livingsafely, nw, issue, severe, thunders...
# 10852  [mh370, aircraft, debris, found, la, reunion, ...
# 10853  [father, three, lose, control, car, overtake, ...
# 10854  [one, three, earthquake, 9km, ssw, anza, calif...
# 10855  [evacuation, order, lift, town, roosevelt, htt...
# 10856  [see, 16yr, old, pkk, suicide, bomber, detonat...
# 10857  [conference, attendee, blue, line, airport, de...
# 10858  [death, toll, suicide, car, bombing, ypg, posi...
# 10859  [break, la, refugio, oil, spill, may, costlier...
# 10860                 [siren, go, forney, tornado, warn]
# 10861  [earthquake, safety, los, angeles, uo, safety,...
# 10862  [official, say, quarantine, place, alabama, ho...
# 10863  [worldnews, fall, powerlines, g, link, tram, u...
# 10864  [flip, side, walmart, bomb, everyone, evacuate...
# 10865  [storm, ri, bad, last, hurricane, city, amp, 3...
# 10866  [suicide, bomber, kill, fifteen, saudi, securi...
# 10867  [stormchase, violent, record, break, ef, five,...
# 10868  [green, line, derailment, chicago, http, co, u...
# 10869  [two, giant, crane, hold, bridge, collapse, ne...
# 10870  [aria_ahrary, thetawniest, control, wild, fire...
# 10871  [m1, ninety-four, one, four, utc, 5km, volcano...
# 10872  [police, investigate, e, bike, collide, car, l...
# 10873  [late, home, raze, northern, california, wildf...
# 10874  [meg, issue, hazardous, weather, outlook, hwo,...
# 10875  [cityofcalgary, activate, municipal, emergency...

# %%
# Stitching together
tokens = []
for i,d in enumerate(test['normalize']):
    tokens.append(' '.join(d))

# %%
test['normalize_stitched'] = tokens

# %%
# Removing "Can't Decide" rows
test.drop(test[test['choose_one'] == "Can't Decide"].index, inplace=True)

# %%
test = test.reset_index(drop=True)

# %%
test.choose_one.value_counts()
# Out:
# Not Relevant    6187
# Relevant        4673
# Name: choose_one, dtype: int64

# %%
def encoder(x):
    if x == 'Relevant':
        return 1
    if x == 'Not Relevant':
        return 0

# %%
test['choose_one'] = test['choose_one'].apply(lambda x: encoder(x))

# %%
test.choose_one.value_counts()
# Out:
# 0    6187
# 1    4673
# Name: choose_one, dtype: int64

# %%
test.to_pickle('final-data2.pickle')
